# %%
install.packages("nortest")
install.packages("tseries")
install.packages("ggplot2")

library(ggplot2)
library(tseries)
library(nortest)
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Registered S3 method overwritten by 'xts':
#   method     from
#   as.zoo.xts zoo
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo

# %%
obitospb = read.csv("anomes_ob.csv")
hosptpb = read.csv("anomes_hospt.csv")
obitosvale = read.csv("anomes_ob_vale.csv")
hosptvale = read.csv("anomes_hospt_vale.csv")

# %%
obitospb <- ts(obitospb[,2])
hosptpb <- ts(hosptpb[,2])
obitosvale <- ts(obitosvale[,2])
hosptvale <- ts(hosptvale[,2])

# %%
ts_obitospb = ts(obitospb, start=c(2009,01), frequency=12)
ts_hosptpb = ts(hosptpb, start=c(2009,01), frequency=12)
ts_obitosvale = ts(obitosvale, start=c(2009,01), frequency=12)
ts_hosptvale = ts(hosptvale, start=c(2009,01), frequency=12)

# %%
lillie.test(obitospb)
# Out:
# 	Lilliefors (Kolmogorov-Smirnov) normality test
#
# data:  obitospb
# D = 0.11427, p-value = 0.0002281

# %%
lillie.test(hosptpb)
# Out:
# 	Lilliefors (Kolmogorov-Smirnov) normality test
#
# data:  hosptpb
# D = 0.03281, p-value = 0.979

# %%
lillie.test(obitosvale)
# Out:
# 	Lilliefors (Kolmogorov-Smirnov) normality test
#
# data:  obitosvale
# D = 0.49106, p-value < 2.2e-16

# %%
lillie.test(hosptvale)
# Out:
# 	Lilliefors (Kolmogorov-Smirnov) normality test
#
# data:  hosptvale
# D = 0.081279, p-value = 0.03239

# %%
adf.test(obitospb, k = 0)
# Out:
# Warning message in adf.test(obitospb, k = 0):
# “p-value smaller than printed p-value”
# 	Augmented Dickey-Fuller Test
#
# data:  obitospb
# Dickey-Fuller = -9.5041, Lag order = 0, p-value = 0.01
# alternative hypothesis: stationary

# %%
adf.test(hosptpb, k = 0)
# Out:
# Warning message in adf.test(hosptpb, k = 0):
# “p-value smaller than printed p-value”
# 	Augmented Dickey-Fuller Test
#
# data:  hosptpb
# Dickey-Fuller = -5.0729, Lag order = 0, p-value = 0.01
# alternative hypothesis: stationary

# %%
adf.test(obitosvale, k = 0)
# Out:
# Warning message in adf.test(obitosvale, k = 0):
# “p-value smaller than printed p-value”
# 	Augmented Dickey-Fuller Test
#
# data:  obitosvale
# Dickey-Fuller = -6.4003, Lag order = 0, p-value = 0.01
# alternative hypothesis: stationary

# %%
adf.test(hosptvale, k = 0)
# Out:
# Warning message in adf.test(hosptvale, k = 0):
# “p-value smaller than printed p-value”
# 	Augmented Dickey-Fuller Test
#
# data:  hosptvale
# Dickey-Fuller = -10.199, Lag order = 0, p-value = 0.01
# alternative hypothesis: stationary

# %%
plot.ts(obitospb,main="Óbitos na Paraíba")
# Out:
# Plot with title “Óbitos na Paraíba”

# %%
plot.ts(hosptpb,main="Hospitalizações na Paraíba")
# Out:
# Plot with title “Hospitalizações na Paraíba”

# %%
plot.ts(obitosvale,main="Óbitos no Vale do Mamanguape")
# Out:
# Plot with title “Óbitos no Vale do Mamanguape”

# %%
plot.ts(hosptvale,main="Hospitalizações no Vale do Mamanguape")
# Out:
# Plot with title “Hospitalizações no Vale do Mamanguape”

# %%
acf(obitospb,lag=48,main="Autocorrelação de óbitos na Paraíba")
# Out:
# Plot with title “Autocorrelação de óbitos na Paraíba”

# %%
acf(hosptpb,lag=48,main="Autocorrelação de hospitalizações na Paraíba")
# Out:
# Plot with title “Autocorrelação de hospitalizações na Paraíba”

# %%
acf(obitosvale,lag=48,main="Autocorrelação de óbitos no Vale do Mamanguape")
# Out:
# Plot with title “Autocorrelação de óbitos no Vale do Mamanguape”

# %%
acf(hosptvale,lag=48,main="Autocorrelação de hospitalizações no Vale do Mamanguape")
# Out:
# Plot with title “Autocorrelação de hospitalizações no Vale do Mamanguape”

# %%
pacf(obitospb,lag=48,main="Autocorrelação parcial de óbitos na Paraíba")
# Out:
# Plot with title “Autocorrelação parcial de óbitos na Paraíba”

# %%
pacf(hosptpb,lag=48,main="Autocorrelação de hospitalizações na Paraíba")
# Out:
# Plot with title “Autocorrelação de hospitalizações na Paraíba”

# %%
pacf(obitosvale,lag=48,main="Autocorrelação parcial de óbitos no Vale do Mamanguape")
# Out:
# Plot with title “Autocorrelação parcial de óbitos no Vale do Mamanguape”

# %%
pacf(hosptvale,lag=48,main="Autocorrelação parcial de hospitalizações no Vale do Mamanguape")
# Out:
# Plot with title “Autocorrelação parcial de hospitalizações no Vale do Mamanguape”

# %%
ajuste.stl_obitospb <- stl(ts_obitospb, "per")
plot(ajuste.stl_obitospb, main="Decomposição da série temporal de óbitos na Paraíba")
# Out:
# Plot with title “Decomposição da série temporal de óbitos na Paraíba”

# %%
ajuste.stl_hosptpb <- stl(ts_hosptpb, "per")
plot(ajuste.stl_hosptpb, main="Decomposição da série temporal de hospitalizações na Paraíba")
# Out:
# Plot with title “Decomposição da série temporal de hospitalizações na Paraíba”

# %%
ajuste.stl_obitosvale <- stl(ts_obitosvale, "per")
plot(ajuste.stl_obitosvale, main="Decomposição da série temporal de óbitos no Vale do Mamanguape")
# Out:
# Plot with title “Decomposição da série temporal de óbitos no Vale do Mamanguape”

# %%
ajuste.stl_hosptvale <- stl(ts_hosptvale, "per")
plot(ajuste.stl_hosptvale, main="Decomposição da série temporal de hospitalizações no Vale do Mamanguape")
# Out:
# Plot with title “Decomposição da série temporal de hospitalizações no Vale do Mamanguape”

# %%
ajuste.sarima_obitospb = arima(obitospb,order=c(6,0,5))
ajuste.sarima_obitospb

ajuste.sarima_hosptpb = arima(hosptpb,order=c(15,0,4))
ajuste.sarima_hosptpb
# Out:
# Warning message in arima(obitospb, order = c(6, 0, 5)):
# “possible convergence problem: optim gave code = 1”
# Call:
# arima(x = obitospb, order = c(6, 0, 5))
#
# Coefficients:
#           ar1     ar2      ar3      ar4     ar5     ar6     ma1      ma2
#       -0,0703  0,2934  -0,5132  -0,0158  0,7066  0,0268  0,2990  -0,3126
# s.e.   0,2151  0,1619   0,1418   0,1827  0,1382  0,1105  0,2009   0,2122
#          ma3     ma4      ma5  intercept
#       0,4800  0,1915  -0,7077     9,2378
# s.e.  0,1644  0,1878   0,1985     0,4165
#
# sigma^2 estimated as 8,606:  log likelihood = -331,43,  aic = 688,87
# Call:
# arima(x = hosptpb, order = c(15, 0, 4))
#
# Coefficients:
#           ar1     ar2      ar3      ar4     ar5     ar6     ar7      ar8
#       -0,2711  1,0918  -0,3497  -0,6450  0,1594  0,1712  0,2573  -0,0321
# s.e.   0,1028  0,1105   0,1561   0,1596  0,1774  0,1856  0,1816   0,1853
#           ar9    ar10    ar11   ar12    ar13    ar14     ar15     ma1      ma2
#       -0,3413  0,1069  0,1713  0,010  0,2973  0,0224  -0,1456  0,6825  -0,6270
# s.e.   0,1852  0,1849  0,1830  0,168  0,1617  0,1150   0,1093  0,0642   0,0552
#          ma3     ma4  intercept
#       0,6824  0,9999   358,1677
# s.e.  0,0586  0,0652    11,5822
#
# sigma^2 estimated as 635,7:  log likelihood = -620,29,  aic = 1282,58

# %%
ajuste.sarima_obitosvale = arima(obitosvale,order=c(1,0,1))
ajuste.sarima_obitosvale

ajuste.sarima_hosptvale = arima(hosptvale,order=c(2,0,2))
ajuste.sarima_hosptvale
# Out:
# Call:
# arima(x = obitosvale, order = c(1, 0, 1))
#
# Coefficients:
#           ar1     ma1  intercept
#       -0,7516  1,0000     1,2546
# s.e.   0,1161  0,0885     0,0957
#
# sigma^2 estimated as 0,3233:  log likelihood = -40,31,  aic = 88,62
# Warning message in arima(hosptvale, order = c(2, 0, 2)):
# “possible convergence problem: optim gave code = 1”
# Call:
# arima(x = hosptvale, order = c(2, 0, 2))
#
# Coefficients:
#           ar1     ar2     ma1      ma2  intercept
#       -0,0046  0,9217  0,1113  -0,8886    13,3472
# s.e.   0,1182  0,1074  0,1692   0,1689     0,9533
#
# sigma^2 estimated as 16,78:  log likelihood = -374,2,  aic = 760,41

# %%
obitos6_pb = obitospb[1:66]
obitos6_pb = ts(obitos6_pb, start=c(2009,01), frequency=12)
ajuste.sarima_obitos6_pb = arima(obitos6_pb,order=c(6,0,5))
pacc_obitos_pb = predict(ajuste.sarima_obitos6_pb, 6)
obitos_reais6_pb <- obitospb[67:72]
obitos_prev6_pb <- pacc_obitos_pb$pred

hospt6_pb = hosptpb[1:66]
hospt6_pb = ts(hospt6_pb, start=c(2009,01), frequency=12)
ajuste.sarima_hospt6_pb = arima(hospt6_pb,order=c(15,0,4))
pacc_hospt_pb = predict(ajuste.sarima_hospt6_pb, 6)
hospt_reais6_pb <- hosptpb[67:72]
hospt_prev6_pb <- pacc_hospt_pb$pred
# Out:
# Warning message in arima(obitos6_pb, order = c(6, 0, 5)):
# “possible convergence problem: optim gave code = 1”Warning message in arima(hospt6_pb, order = c(15, 0, 4)):
# “possible convergence problem: optim gave code = 1”

# %%
obitos6_vale = obitosvale[1:66]
obitos6_vale = ts(obitos6_vale, start=c(2009,01), frequency=12)
ajuste.sarima_obitos6_vale = arima(obitos6_vale,order=c(1,0,1))
pacc_obitos_vale = predict(ajuste.sarima_obitos6_vale, 6)
obitos_reais6_vale <- obitosvale[67:72]
obitos_prev6_vale <- pacc_obitos_vale$pred


hospt6_vale = hosptvale[1:66]
hospt6_pb = ts(hospt6_vale, start=c(2009,01), frequency=12)
ajuste.sarima_hospt6_vale = arima(hospt6_vale,order=c(2,0,2))
pacc_hospt_vale = predict(ajuste.sarima_hospt6_vale, 6)
hospt_reais6_vale <- hosptvale[67:72]
hospt_prev6_vale <- pacc_hospt_vale$pred

# %%
h_obitos_pb = 6
C1_obitos_pb = sum(obitos_reais6_pb) - sum(obitos_prev6_pb)
C2_obitos_pb = ((sum(obitos_reais6_pb) - sum(obitos_prev6_pb)) / sum(obitos_reais6_pb)) * 100
C3_obitos_pb = (1/h_obitos_pb) * sum((obitos_reais6_pb - obitos_prev6_pb) ^ 2)
C4_obitos_pb = (1/h_obitos_pb) * sum(abs(obitos_reais6_pb - obitos_prev6_pb))


h_hospt_pb = 6
C1_hospt_pb = sum(hospt_reais6_pb) - sum(hospt_prev6_pb)
C2_hospt_pb = ((sum(hospt_reais6_pb) - sum(hospt_prev6_pb)) / sum(hospt_reais6_pb)) * 100
C3_hospt_pb = (1/h_hospt_pb) * sum((hospt_reais6_pb - hospt_prev6_pb) ^ 2)
C4_hospt_pb = (1/h_hospt_pb) * sum(abs(hospt_reais6_pb - hospt_prev6_pb))

# %%
h_obitos_vale = 6
C1_obitos_vale = sum(obitos_reais6_vale) - sum(obitos_prev6_vale)
C2_obitos_vale = ((sum(obitos_reais6_vale) - sum(obitos_prev6_vale)) / sum(obitos_reais6_vale)) * 100
C3_obitos_vale = (1/h_obitos_vale) * sum((obitos_reais6_vale - obitos_prev6_vale) ^ 2)
C4_obitos_vale = (1/h_obitos_vale) * sum(abs(obitos_reais6_vale - obitos_prev6_vale))


h_hospt_vale = 6
C1_hospt_vale = sum(hospt_reais6_vale) - sum(hospt_prev6_vale)
C2_hospt_vale = ((sum(hospt_reais6_vale) - sum(hospt_prev6_vale)) / sum(hospt_reais6_vale)) * 100
C3_hospt_vale = (1/h_hospt_vale) * sum((hospt_reais6_vale - hospt_prev6_vale) ^ 2)
C4_hospt_vale = (1/h_hospt_vale) * sum(abs(hospt_reais6_vale - hospt_prev6_vale))

# %%
pacc_obitos_pb$pred + 1.96*pacc_obitos_pb$se
pacc_obitos_pb$pred - 1.96*pacc_obitos_pb$se


pacc_hospt_pb$pred + 1.96*pacc_hospt_pb$se
pacc_hospt_pb$pred - 1.96*pacc_hospt_pb$se
# Out:
# ERROR while rich displaying an object: Error in arr_partition(a, rows, cols): rows >= 2L is not TRUE
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_text.ts(obj)
# 9. repr_ts_generic(obj, repr_text.matrix, ...)
# 10. repr_func(m, ..., rows = nrow(m), cols = ncol(m))
# 11. ellip_limit_arr(obj, ...)
# 12. arr_partition(a, rows, cols)
# 13. stopifnot(rows >= 2L, cols >= 2L)
# ERROR while rich displaying an object: Error in arr_partition(a, rows, cols): rows >= 2L is not TRUE
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_text.ts(obj)
# 9. repr_ts_generic(obj, repr_text.matrix, ...)
# 10. repr_func(m, ..., rows = nrow(m), cols = ncol(m))
# 11. ellip_limit_arr(obj, ...)
# 12. arr_partition(a, rows, cols)
# 13. stopifnot(rows >= 2L, cols >= 2L)
# ERROR while rich displaying an object: Error in arr_partition(a, rows, cols): rows >= 2L is not TRUE
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_text.ts(obj)
# 9. repr_ts_generic(obj, repr_text.matrix, ...)
# 10. repr_func(m, ..., rows = nrow(m), cols = ncol(m))
# 11. ellip_limit_arr(obj, ...)
# 12. arr_partition(a, rows, cols)
# 13. stopifnot(rows >= 2L, cols >= 2L)
# ERROR while rich displaying an object: Error in arr_partition(a, rows, cols): rows >= 2L is not TRUE
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_text.ts(obj)
# 9. repr_ts_generic(obj, repr_text.matrix, ...)
# 10. repr_func(m, ..., rows = nrow(m), cols = ncol(m))
# 11. ellip_limit_arr(obj, ...)
# 12. arr_partition(a, rows, cols)
# 13. stopifnot(rows >= 2L, cols >= 2L)

# %%
pacc_obitos_vale$pred + 1.96*pacc_obitos_vale$se
pacc_obitos_vale$pred - 1.96*pacc_obitos_vale$se


pacc_hospt_vale$pred + 1.96*pacc_hospt_vale$se
pacc_hospt_vale$pred - 1.96*pacc_hospt_vale$se
# Out:
# ERROR while rich displaying an object: Error in arr_partition(a, rows, cols): rows >= 2L is not TRUE
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_text.ts(obj)
# 9. repr_ts_generic(obj, repr_text.matrix, ...)
# 10. repr_func(m, ..., rows = nrow(m), cols = ncol(m))
# 11. ellip_limit_arr(obj, ...)
# 12. arr_partition(a, rows, cols)
# 13. stopifnot(rows >= 2L, cols >= 2L)
# ERROR while rich displaying an object: Error in arr_partition(a, rows, cols): rows >= 2L is not TRUE
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_text.ts(obj)
# 9. repr_ts_generic(obj, repr_text.matrix, ...)
# 10. repr_func(m, ..., rows = nrow(m), cols = ncol(m))
# 11. ellip_limit_arr(obj, ...)
# 12. arr_partition(a, rows, cols)
# 13. stopifnot(rows >= 2L, cols >= 2L)
# ERROR while rich displaying an object: Error in if (many_rows) {: argumento tem comprimento zero
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_text.ts(obj)
# 9. repr_ts_generic(obj, repr_text.matrix, ...)
# 10. repr_func(m, ..., rows = nrow(m), cols = ncol(m))
# 11. ellip_limit_arr(obj, ...)
# 12. arr_partition(a, rows, cols)
# ERROR while rich displaying an object: Error in if (many_rows) {: argumento tem comprimento zero
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_text.ts(obj)
# 9. repr_ts_generic(obj, repr_text.matrix, ...)
# 10. repr_func(m, ..., rows = nrow(m), cols = ncol(m))
# 11. ellip_limit_arr(obj, ...)
# 12. arr_partition(a, rows, cols)

# %%
tsdiag(ajuste.sarima_obitos6_pb)
title("Teste de normalidade dos resíduos da previsão de óbitos na Paraíba",cex.main=0.90)
# Out:
# Plot with title “Teste de normalidade dos resíduos da previsão de óbitos na Paraíba”

# %%
tsdiag(ajuste.sarima_hospt6_pb)
title("Teste de normalidade dos resíduos da previsão de hospitalizações na Paraíba",cex.main=0.90)
# Out:
# Plot with title “Teste de normalidade dos resíduos da previsão de hospitalizações na Paraíba”

# %%
tsdiag(ajuste.sarima_obitos6_vale)
title("Teste de normalidade dos resíduos da previsão de óbitos no Vale do Mamanguape",cex.main=0.90)
# Out:
# Plot with title “Teste de normalidade dos resíduos da previsão de óbitos no Vale do Mamanguape”

# %%
tsdiag(ajuste.sarima_hospt6_vale)
title("Teste de normalidade dos resíduos da previsão de hospitalizações no Vale do Mamanguape",cex.main=0.90)
# Out:
# Plot with title “Teste de normalidade dos resíduos da previsão de hospitalizações no Vale do Mamanguape”

# %%
hist(residuals(ajuste.sarima_obitos6_pb), main="Histograma de resíduos das previsões de óbitos na Paraíba")
# Out:
# Plot with title “Histograma de resíduos das previsões de óbitos na Paraíba”

# %%
hist(residuals(ajuste.sarima_hospt6_pb), main="Histograma de resíduos das previsões de hospitalizações na Paraíba")
# Out:
# Plot with title “Histograma de resíduos das previsões de hospitalizações na Paraíba”

# %%
hist(residuals(ajuste.sarima_obitos6_vale), main="Histograma de resíduos das previsões de óbitos \n no Vale do Mamanguape")
# Out:
# Plot with title “Histograma de resíduos das previsões de óbitos
#  no Vale do Mamanguape”

# %%
hist(residuals(ajuste.sarima_hospt6_vale), main="Histograma de resíduos das previsões de óbitos no Vale do Mamanguape")
# Out:
# Plot with title “Histograma de resíduos das previsões de óbitos no Vale do Mamanguape”

# %%
qqnorm(residuals(ajuste.sarima_obitos6_pb), main="Resíduos da previsão de óbitos na Paraíba ARMA(6,5)")
# Out:
# Plot with title “Resíduos da previsão de óbitos na Paraíba ARMA(6,5)”

# %%
qqnorm(residuals(ajuste.sarima_obitos6_vale), main="Resíduos da previsão de óbitos no Vale do Mamanguape ARMA(1,1)")
# Out:
# Plot with title “Resíduos da previsão de óbitos no Vale do Mamanguape ARMA(1,1)”

# %%
qqnorm(residuals(ajuste.sarima_hospt6_pb), main="Resíduos da previsão de hospitalizações na Paraíba ARMA (15,4)")
# Out:
# Plot with title “Resíduos da previsão de hospitalizações na Paraíba ARMA (15,4)”

# %%
qqnorm(residuals(ajuste.sarima_hospt6_vale), main="Resíduos da previsão de hospitalizações no Vale do Mamanguape ARMA (2,2)")
# Out:
# Plot with title “Resíduos da previsão de hospitalizações no Vale do Mamanguape ARMA (2,2)”

# %%
lillie.test(residuals(ajuste.sarima_obitos6_pb))
# Out:
# 	Lilliefors (Kolmogorov-Smirnov) normality test
#
# data:  residuals(ajuste.sarima_obitos6_pb)
# D = 0,086361, p-value = 0,2571

# %%
lillie.test(residuals(ajuste.sarima_hospt6_pb))
# Out:
# 	Lilliefors (Kolmogorov-Smirnov) normality test
#
# data:  residuals(ajuste.sarima_hospt6_pb)
# D = 0,090664, p-value = 0,1963

# %%
lillie.test(residuals(ajuste.sarima_obitos6_vale))
# Out:
# 	Lilliefors (Kolmogorov-Smirnov) normality test
#
# data:  residuals(ajuste.sarima_obitos6_vale)
# D = 0,30901, p-value = 4,446e-12

# %%
lillie.test(residuals(ajuste.sarima_hospt6_vale))
# Out:
# 	Lilliefors (Kolmogorov-Smirnov) normality test
#
# data:  residuals(ajuste.sarima_hospt6_vale)
# D = 0,065127, p-value = 0,6966
